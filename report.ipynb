# %% [markdown]
# # **ATIVIDADE 1**

# %%
# Bibliotecas
import pandas as pd

# %% [markdown]
# # **Analisando o arquivo movies**

# %%
# URLS com os dataset para analise

url_movies = "https://raw.githubusercontent.com/FabianoLuizonCampos/python-movie-analyses/refs/heads/main/ml-latest-small/movies.csv"

# %% [markdown]
# # **Dataset Movies**

# %%
# Importando dataset do repositório do github
df = pd.read_csv(url_movies)

# %%
# Imprimindo Cabeçario

df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Imprimindo os últimos registros
df.tail()
# Out:
#       movieId                                      title  \
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                genres
# 9737  Action|Animation|Comedy|Fantasy
# 9738         Animation|Comedy|Fantasy
# 9739                            Drama
# 9740                 Action|Animation
# 9741                           Comedy

# %%
# Tipo de dados
df.dtypes
# Out:
# movieId     int64
# title      object
# genres     object
# dtype: object

# %%
# Quantidade de registros e o número de colunas
df.shape
# Out:
# (9742, 3)

# %%
# Quantidades de linhas ou registro
df.shape[0]
# Qunatidade de colunas / atributos / caracteristicas
df.shape[1]

print(f'Linhas: {df.shape[0]}')
print(f'Colunas: {df.shape[1]}')
# Out:
# Linhas: 9742
# Colunas: 3

# %%
# Informação do datset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %%
df.describe()
# Out:
#              movieId
# count    9742.000000
# mean    42200.353623
# std     52160.494854
# min         1.000000
# 25%      3248.250000
# 50%      7300.000000
# 75%     76232.000000
# max    193609.000000
